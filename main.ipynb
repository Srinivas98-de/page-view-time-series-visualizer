# %%
# Run this cell to import your visualizer functions
import time_series_visualizer as ts

# Draw and display the line plot
fig1 = ts.draw_line_plot()
fig1.show()

# Draw and display the bar plot
fig2 = ts.draw_bar_plot()
fig2.show()

# Draw and display the box plots
fig3 = ts.draw_box_plot()
fig3.show()
# Out:
# C:\Users\srinivas\AppData\Local\Temp\ipykernel_25212\28920337.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()
# C:\Users\srinivas\AppData\Local\Temp\ipykernel_25212\28920337.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig2.show()
# C:\Users\srinivas\AppData\Local\Temp\ipykernel_25212\28920337.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig3.show()

# %%
import os
print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', 'bar_plot.png', 'box_plot.png', 'fcc-forum-pageviews.csv', 'line_plot.png', 'main.ipynb', 'main.py', 'test_module.py', 'time_series_visualizer.ipynb', 'time_series_visualizer.py', '__pycache__']
